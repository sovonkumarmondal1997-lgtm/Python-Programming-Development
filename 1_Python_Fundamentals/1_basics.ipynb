# %% [markdown]
# Why We Should Learn Python

# %%
# 1. Design Philosophy:

"""
Python is easy to learn. Python coding structure is not like Java, C and C++.

To code in Java, C and C++ there are certain rules and regulations have to follow,
otherwise it shows error.

Python rules and regulations are easy for cooding, which anyone can know and understand and start coding.
"""
# Out:
# '\nPython is easy to learn. Python coding structure is not like Java, C and C++ \n\nTo code in Java, C and C++ there are certain rules and regulations have to follow,\notherwise it shows error\n\nPython rules and regulations are easy for cooding, which anyone can know and understand and start cooding\n'

# %%
# 2. Batteries Included:

"""
Python provides built-in modules for better coding experience like math,sys,os etc. here we do not 
need to build anything from the scratch.

Python converts most common tasks like file handling,working with JSON,HTTP request, data compression,
regular expression all are already available.
example: JSON modules to parse APIs

Since lots of tools available it increases developmnt speed

Python provides standard libraries which are maintained by python itself which are widely used

Python reduces dependency on extrnal libraries which are installed via pip (third party libraries)

"""
# Out:
# '\nPython provides built-in modules for better coding experience like math,sys,os etc. here we do not \nneed to build anything from the scratch.\n\nPython converts most common tasks like file handling,working with JSON,HTTP request, data compression,\nregular expression all are already available.\nexample: JSON modules to parse APIs\n\nSince lots of tools available it increases developmnt speed\n\nPython provides standard libraries which are maintained by python itself which are widely used\n\nPython reduces dependency on extrnal libraries which are installed via pip (third party libraries)\n\n'

# %%
# 3. General Purpose:

"""
Python is not only used in data field it is used in different different field also 

Like we can use python to build website, apps like facebook or meta

Like we can use it in Machine learning and Artificial Intelligence field also 

main thing is we can use python for general purpose not a specific purpose
"""
# Out:
# '\nPython is not onl used in data field it is used in different different field also \n\nLike we can use python to build website, apps like facebook or meta\n\nLike we can use it in Machine learning and Artificial Intelligence field also \n\nmain thing is we can use python for general purpose not a specific purpose\n'

# %%
# 4. Libraries and Communities:

"""
Python has a wide range of community and so many usuful libraries which are very helpful 
"""
