# %%
# Namespace and Scope:

# %%
"""
Q1: Write Person Class as given below and then display it's namespace.
Class Name - Person

Attributes:
name - public
state - public
city - private
age - private

Methods:
address - public
It give address of the person as "<name>, <city>, <state>"
"""
# Out:
# '\nQ1: Write Person Class as given below and then display it\'s namespace.\nClass Name - Person\n\nAttributes:\nname - public\nstate - public\ncity - private\nage - private\n\nMethods:\naddress - public\nIt give address of the person as "<name>, <city>, <state>"\n'

# %%
class Person:
    def __init__(self, name, state, city, age):
        self.name = name  # public attribute
        self.state = state  # public attribute
        self.__city = city  # private attribute
        self.__age = age  # private attribute

    def address(self):
        return f"{self.name}, {self.__city}, {self.state}"

# %%
# Create an instance of the Person class
person = Person("John Doe", "California", "Los Angeles", 30)
# Display the namespace of the person instance
print(person.__dict__)
print(person.address())
# Out:
# {'name': 'John Doe', 'state': 'California', '_Person__city': 'Los Angeles', '_Person__age': 30}
# John Doe, Los Angeles, California

# %%
"""
Q2: Write a program to show namespace of object/instance of above(Person) class.
"""
# Out:
# '\nQ2: Write a program to show namespace of object/instance of above(Person) class.\n'

# %%
p = Person("Alice", "New York", "New York City", 25)
print(p.__dict__)
print(p.address())
# Out:
# {'name': 'Alice', 'state': 'New York', '_Person__city': 'New York City', '_Person__age': 25}
# Alice, New York City, New York

# %%
"""
Q3: Write a recursive program to to calculate gcd and print no. of function calls taken to find the solution.
gcd(5,10) -> result in 5 as gcd and function call 4
"""
# Out:
# '\nQ3: Write a recursive program to to calculate gcd and print no. of function calls taken to find the solution.\ngcd(5,10) -> result in 5 as gcd and function call 4\n'

# %%
call_count = 0
def gcd(a, b):
    global call_count
    call_count += 1
    if b == 0:
        return a
    else:
        return gcd(b, a % b)

# %%
gcd_result = gcd(10, 20)
print(f"GCD: {gcd_result}", f"Function Calls: {call_count}")
# Out:
# GCD: 10 Function Calls: 8

# %%
"""
Itterator And Generator
Q4: Create MyEnumerate class,
Create your own MyEnumerate class such that someone can use it instead of enumerate. It will need to return a tuple with each iteration, with the first element in the tuple being the index (starting with 0) and the second element being the current element from the underlying data structure. Trying to use MyEnumerate with a noniterable argument will result in an error.

for index, letter in MyEnumerate('abc'):
    print(f'{index} : {letter}')
Output:

0 : a
1 : b
2 : c
"""
# Out:
# "\nItterator And Generator\nQ4: Create MyEnumerate class,\nCreate your own MyEnumerate class such that someone can use it instead of enumerate. It will need to return a tuple with each iteration, with the first element in the tuple being the index (starting with 0) and the second element being the current element from the underlying data structure. Trying to use MyEnumerate with a noniterable argument will result in an error.\n\nfor index, letter in MyEnumerate('abc'):\n    print(f'{index} : {letter}')\nOutput:\n\n0 : a\n1 : b\n2 : c\n"

# %%
l = [1, 2, 3, 4, 5]
class MyEnumerate:
    def __init__(self, iterable):
        self.iterable = iterable
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.index < len(self.iterable):
            result = (self.index, self.iterable[self.index])
            self.index += 1
            return result
        else:
            raise StopIteration
        
for index, letter in MyEnumerate('abc'):
    print(f'{index} : {letter}')
# Out:
# 0 : a
# 1 : b
# 2 : c

# %%
"""
Q5: Iterate in circle
Define a class, Circle, that takes two arguments when defined: a sequence and a number. The idea is that the object will then return elements the defined number of times. If the number is greater than the number of elements, then the sequence repeats as necessary. You can define an another class used as a helper (like I call CircleIterator).

c = Circle('abc', 5)
d = Circle('abc', 7)
print(list(c))
print(list(d))
Output

[a, b, c, a, b]
[a, b, c, a, b, c, a]
"""
# Out:
# "\nQ5: Iterate in circle\nDefine a class, Circle, that takes two arguments when defined: a sequence and a number. The idea is that the object will then return elements the defined number of times. If the number is greater than the number of elements, then the sequence repeats as necessary. You can define an another class used as a helper (like I call CircleIterator).\n\nc = Circle('abc', 5)\nd = Circle('abc', 7)\nprint(list(c))\nprint(list(d))\nOutput\n\n[a, b, c, a, b]\n[a, b, c, a, b, c, a]\n"

# %%
class Circle:
    def __init__(self, sequence, number):
        self.sequence = sequence
        self.number = number

    def __iter__(self):
        return CircleIterator(self.sequence, self.number)

class CircleIterator:
    def __init__(self, sequence, number):
        self.sequence = sequence
        self.number = number
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.index < self.number:
            result = self.sequence[self.index % len(self.sequence)]
            self.index += 1
            return result
        else:
            raise StopIteration

# %%
c = Circle('abc', 5)
d = Circle('abc', 7)
print(list(c))
print(list(d))
# Out:
# ['a', 'b', 'c', 'a', 'b']
# ['a', 'b', 'c', 'a', 'b', 'c', 'a']

# %%
"""
Q6: Generator time elapsed:
Write a generator function whose argument must be iterable. With each iteration, the generator will return a two-element tuple. The first element in the tuple will be an integer indicating how many seconds have passed since the previous iteration. The tuple’s second element will be the next item from the passed argument.

Note that the timing should be relative to the previous iteration, not when the generator was first created or invoked. Thus the timing number in the first iteration will be 0

for t in elapsed_since('abcd'):
    print(t)
    time.sleep(2)
Output:

(0.0, 'a')
(2.005651817999933, 'b')
(2.0023095009998997, 'c')
(2.001949742000079, 'd')
Note: Your output may differ because of diffrent system has different processing configuration.
"""
# Out:
# "\nQ6: Generator time elapsed:\nWrite a generator function whose argument must be iterable. With each iteration, the generator will return a two-element tuple. The first element in the tuple will be an integer indicating how many seconds have passed since the previous iteration. The tuple’s second element will be the next item from the passed argument.\n\nNote that the timing should be relative to the previous iteration, not when the generator was first created or invoked. Thus the timing number in the first iteration will be 0\n\nfor t in elapsed_since('abcd'):\n    print(t)\n    time.sleep(2)\nOutput:\n\n(0.0, 'a')\n(2.005651817999933, 'b')\n(2.0023095009998997, 'c')\n(2.001949742000079, 'd')\nNote: Your output may differ because of diffrent system has different processing configuration.\n"

# %%
import time

def elapsed_since(iterable):
    first = True
    previous_time = None

    for item in iterable:
        current_time = time.time()

        if first:
            yield (0.0, item)
            first = False
        else:
            yield (current_time - previous_time, item)

        previous_time = time.time()


for t in elapsed_since('abcd'):
    print(t)
    time.sleep(2)
# Out:
# (0.0, 'a')
# (1.1444091796875e-05, 'b')
# (2.1457672119140625e-06, 'c')
# (1.430511474609375e-06, 'd')

# %%
# Decorators:

# %%
"""
Q7: Write a Python program to make a chain of function decorators (bold, italic, underline etc.) on a given function which prints "hello world"
def hello():
    return "hello world"
bold - wrap string with <b> tag. <b>Str</b>
italic - wrap string with <i> tag. <i>Str</i>
underline- wrap string with <u> tag. <u>Str</u>
"""
# Out:
# '\nQ7: Write a Python program to make a chain of function decorators (bold, italic, underline etc.) on a given function which prints "hello world"\ndef hello():\n    return "hello world"\nbold - wrap string with <b> tag. <b>Str</b>\nitalic - wrap string with <i> tag. <i>Str</i>\nunderline- wrap string with <u> tag. <u>Str</u>\n'

# %%
def make_bold(func):
    def wrapper():
        return f"<b>{func()}</b>"
    return wrapper


def make_italic(func):
    def wrapper():
        return f"<i>{func()}</i>"
    return wrapper


def make_underline(func):
    def wrapper():
        return f"<u>{func()}</u>"
    return wrapper


@make_bold
@make_italic
@make_underline
def hello():
    return "hello world"

# %%
print(hello())
# Out:
# <b><i><u>hello world</u></i></b>

# %%
"""
Q8: Write a decorator called printer which causes any decorated function to print their return values. If the return value of a given function is None, printer should do nothing.
"""
# Out:
# '\nQ8: Write a decorator called printer which causes any decorated function to print their return values. If the return value of a given function is None, printer should do nothing.\n'

# %%
def printer(func):
    def wrapper(*args, **kwargs):
        result = func(*args, **kwargs)

        if result is not None:
            print(result)

        return result

    return wrapper


@printer
def hello():
    return "Hello, World!"

# %%
hello()
# Out:
# Hello, World!
# 'Hello, World!'

# %%
"""
Q9: Make a decorator which calls a given function twice. You can assume the functions don't return anything important, but they may take arguments.

# Lets say given function 
def hello(string):
    print(string)

# on calling after specified decorator is inplaced
hello('hello')

Output:
hello
hello
"""
# Out:
# "\nQ9: Make a decorator which calls a given function twice. You can assume the functions don't return anything important, but they may take arguments.\n\n# Lets say given function \ndef hello(string):\n    print(string)\n\n# on calling after specified decorator is inplaced\nhello('hello')\n\nOutput:\nhello\nhello\n"

# %%
def double(func):
    def wrapper(*args, **kwargs):
        func(*args, **kwargs)
        func(*args, **kwargs)
    return wrapper


@double
def hello(string):
    print(string)

# %%
hello('hello')
# Out:
# hello
# hello

# %%
"""
Q10: Write a decorator which doubles the return value of any function. And test that decoratos is working correctly or not using asert.
add(2,3) -> result in 10. Without decorator it should be 5.
"""
# Out:
# '\nQ10: Write a decorator which doubles the return value of any function. And test that decoratos is working correctly or not using asert.\nadd(2,3) -> result in 10. Without decorator it should be 5.\n'

# %%
def double_return(func):
    def wrapper(*args, **kwargs):
        return 2 * func(*args, **kwargs)
    return wrapper


@double_return
def add(a, b):
    return a + b


result = add(2, 3)

assert result == 10, f"Expected 10, but got {result}"

print("Assertion passed. Result =", result)
# Out:
# Assertion passed. Result = 10
