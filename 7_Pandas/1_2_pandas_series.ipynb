# %% [markdown]
# Series using read_csv:

# %%
import numpy as np
import pandas as pd

# %%
# with one column
subs = pd.read_csv(r'D:\Python Programming & Development\7_Pandas\subs.csv')
print(subs)
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# with 2 columns
vk = pd.read_csv(
    'D:/Python Programming & Development/7_Pandas/kohli_ipl.csv',
    index_col='match_no'
).squeeze("columns")

print(vk)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# with 2 columns
movies = pd.read_csv(
    'D:/Python Programming & Development/7_Pandas/bollywood.csv',
    index_col='movie'
).squeeze("columns")

print(movies)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# Series Methods:

# %%
# head and tail:
print(subs.head())
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
print(vk.head(3))
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
print(movies.head(15))
# Out:
# movie
# Uri: The Surgical Strike                       Vicky Kaushal
# Battalion 609                                    Vicky Ahuja
# The Accidental Prime Minister (film)             Anupam Kher
# Why Cheat India                                Emraan Hashmi
# Evening Shadows                             Mona Ambegaonkar
# Soni (film)                             Geetika Vidya Ohlyan
# Fraud Saiyaan                                   Arshad Warsi
# Bombairiya                                      Radhika Apte
# Manikarnika: The Queen of Jhansi              Kangana Ranaut
# Thackeray (film)                         Nawazuddin Siddiqui
# Amavas                                             Ali Asgar
# Gully Boy                                      Ranveer Singh
# Hum Chaar                                        Prit Kamani
# Total Dhamaal                                     Ajay Devgn
# Sonchiriya                              Sushant Singh Rajput
# Name: lead, dtype: str

# %%
print(subs.tail())
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
print(vk.tail(10))
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
print(movies.tail(5))
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: str

# %%
# sample:
print(subs.sample())
# Out:
#      Subscribers gained
# 159                 118

# %%
print(movies.sample(10))
# Out:
# movie
# Batla House                 John Abraham
# Vaastu Shastra (film)        Vicky Ahuja
# Stanley Ka Dabba         Partho A. Gupte
# Rokkk                    Tanushree Dutta
# Dhoop                            Om Puri
# Mitron                   Jackky Bhagnani
# Shart: The Challenge      Tusshar Kapoor
# Contract (2008 film)      Adhvik Mahajan
# Zed Plus                   Vinod Acharya
# Love Aaj Kal               Saif Ali Khan
# Name: lead, dtype: str

# %%
# value_counts: movies
print(movies.value_counts())
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values: ascending
print(vk.sort_values())
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
# sort_values: descending
print(vk.sort_values(ascending=False))
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
print(vk.sort_values(ascending=False).head(1))
# Out:
# match_no
# 128    113
# Name: runs, dtype: int64

# %%
print(vk.sort_values(ascending=False).head(1).values)
# Out:
# [113]

# %%
print(vk.sort_values(ascending=False).head(1).values[0])
# Out:
# 113

# %%
print(vk.sort_values(ascending=False)) # after changing it does not change the original
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
print(vk)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
print(vk.sort_values(inplace=True)) # it change the vk value permanently
# Out:
# None

# %%
print(vk)
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64
