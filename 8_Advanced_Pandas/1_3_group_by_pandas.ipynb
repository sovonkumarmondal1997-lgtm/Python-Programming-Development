# %% [markdown]
# ## GroupBy Attributes:
#
# ### Attribute:
#
# groups : Dictionary mapping group names to row indices
#
# indices : Dictionary mapping group names to integer positions
#
# ngroups : Number of groups
#
# ndim : Number of dimensions of the grouped object
#
# obj : Original DataFrame or Series being grouped
#
# dtypes : Data types of grouped columns (mainly for DataFrameGroupBy)
