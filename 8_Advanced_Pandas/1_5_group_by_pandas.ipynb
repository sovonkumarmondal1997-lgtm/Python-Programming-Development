# %% [markdown]
# ## Selection Methods:
#
# ### Method:
#
# get_group() : Extract a specific group
#
# first() : First row in each group
#
# last() : Last row in each group
#
# nth() :	Nth row in each group
#
# head() : First n rows of each group
#
# tail() : Last n rows of each group
